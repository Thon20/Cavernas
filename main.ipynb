# %%
import polars as pl
import folium
from shapely import wkt

# %%
df = pl.read_csv('caves.csv')

# %%
df.shape
# Out:
# (12861, 8)

# %%
df.head()
# Out:
# shape: (5, 8)
# ┌─────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────┐
# │     ┆ itemLabel  ┆ coordinate_l ┆ countryLabe ┆ temperature ┆ vertical_de ┆ elevation_a ┆ length │
# │ --- ┆ ---        ┆ ocation      ┆ l           ┆ ---         ┆ pth         ┆ bove_sea_le ┆ ---    │
# │ i64 ┆ str        ┆ ---          ┆ ---         ┆ str         ┆ ---         ┆ vel         ┆ f64    │
# │     ┆            ┆ str          ┆ str         ┆             ┆ f64         ┆ ---         ┆        │
# │     ┆            ┆              ┆             ┆             ┆             ┆ f64         ┆        │
# ╞═════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════╡
# │ 0   ┆ Q100269443 ┆ Point(8.2849 ┆ Alemanha    ┆ null        ┆ null        ┆ null        ┆ null   │
# │     ┆            ┆ 5 52.1166)   ┆             ┆             ┆             ┆             ┆        │
# │ 1   ┆ Q100757214 ┆ Point(8.2400 ┆ Alemanha    ┆ null        ┆ null        ┆ null        ┆ null   │
# │     ┆            ┆ 99           ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 49.565309)   ┆             ┆             ┆             ┆             ┆        │
# │ 2   ┆ Q1009597   ┆ Point(7.6647 ┆ Alemanha    ┆ null        ┆ null        ┆ null        ┆ null   │
# │     ┆            ┆ 2222         ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 51.3675)     ┆             ┆             ┆             ┆             ┆        │
# │ 3   ┆ Q101579973 ┆ Point(2.6650 ┆ França      ┆ null        ┆ null        ┆ 115.0       ┆ 31.0   │
# │     ┆            ┆ 1 48.40216)  ┆             ┆             ┆             ┆             ┆        │
# │ 4   ┆ Q102178845 ┆ Point(22.228 ┆ Sérvia      ┆ null        ┆ null        ┆ null        ┆ null   │
# │     ┆            ┆ 41 44.46235) ┆             ┆             ┆             ┆             ┆        │
# └─────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────┘

# %%
df = df.with_columns(pl.col('temperature').cast(pl.Float64()))

# %%
df_brasil = df.filter(
    pl.col('countryLabel') == 'Brasil'
)

# %%
df_brasil.head()
# Out:
# shape: (5, 8)
# ┌──────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┬────────┐
# │      ┆ itemLabel   ┆ coordinate_ ┆ countryLabe ┆ temperature ┆ vertical_de ┆ elevation_ ┆ length │
# │ ---  ┆ ---         ┆ location    ┆ l           ┆ ---         ┆ pth         ┆ above_sea_ ┆ ---    │
# │ i64  ┆ str         ┆ ---         ┆ ---         ┆ f64         ┆ ---         ┆ level      ┆ f64    │
# │      ┆             ┆ str         ┆ str         ┆             ┆ f64         ┆ ---        ┆        │
# │      ┆             ┆             ┆             ┆             ┆             ┆ f64        ┆        │
# ╞══════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╪════════╡
# │ 120  ┆ Q114347515  ┆ Point(-40.5 ┆ Brasil      ┆ null        ┆ null        ┆ null       ┆ null   │
# │      ┆             ┆ 70406       ┆             ┆             ┆             ┆            ┆        │
# │      ┆             ┆ -20.180847) ┆             ┆             ┆             ┆            ┆        │
# │ 3874 ┆ Abismo Ouro ┆ Point(-48.6 ┆ Brasil      ┆ null        ┆ null        ┆ null       ┆ null   │
# │      ┆ Grosso      ┆ 795         ┆             ┆             ┆             ┆            ┆        │
# │      ┆             ┆ -24.5446)   ┆             ┆             ┆             ┆            ┆        │
# │ 4136 ┆ Areado      ┆ Point(-46.3 ┆ Brasil      ┆ null        ┆ null        ┆ null       ┆ null   │
# │      ┆ Grande      ┆ 671         ┆             ┆             ┆             ┆            ┆        │
# │      ┆             ┆ -13.6685)   ┆             ┆             ┆             ┆            ┆        │
# │ 4809 ┆ Cave of     ┆ Point(-55.3 ┆ Brasil      ┆ null        ┆ null        ┆ 683.0      ┆ null   │
# │      ┆ Saint       ┆ 8311        ┆             ┆             ┆             ┆            ┆        │
# │      ┆ Vincent     ┆ -15.8688)   ┆             ┆             ┆             ┆            ┆        │
# │ 4849 ┆ Caverna     ┆ Point(-55.2 ┆ Brasil      ┆ null        ┆ null        ┆ null       ┆ null   │
# │      ┆ Aroe Jari   ┆ 93          ┆             ┆             ┆             ┆            ┆        │
# │      ┆             ┆ -15.3626)   ┆             ┆             ┆             ┆            ┆        │
# └──────┴─────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┴────────┘

# %%
count_country = df.group_by('countryLabel').agg(pl.count('countryLabel').alias('count')).sort('count', descending=True)
print(count_country.head(10))
# Out:
# shape: (10, 2)
# ┌──────────────────────┬───────┐
# │ countryLabel         ┆ count │
# │ ---                  ┆ ---   │
# │ str                  ┆ u32   │
# ╞══════════════════════╪═══════╡
# │ Espanha              ┆ 2838  │
# │ Alemanha             ┆ 1004  │
# │ Polónia              ┆ 888   │
# │ França               ┆ 659   │
# │ Hungria              ┆ 584   │
# │ Brasil               ┆ 517   │
# │ Bulgária             ┆ 444   │
# │ Reino Unido          ┆ 411   │
# │ Estados Unidos       ┆ 336   │
# │ Bósnia e Herzegovina ┆ 285   │
# └──────────────────────┴───────┘

# %%
brasil_count = count_country.filter(
    pl.col('countryLabel') == 'Brasil'
)
print(brasil_count)
# Out:
# shape: (1, 2)
# ┌──────────────┬───────┐
# │ countryLabel ┆ count │
# │ ---          ┆ ---   │
# │ str          ┆ u32   │
# ╞══════════════╪═══════╡
# │ Brasil       ┆ 517   │
# └──────────────┴───────┘

# %%
temperature = (
    df.group_by('countryLabel')
    .agg(
        (pl.col('temperature').mean().alias('mean_temperature'))
    )
    .filter(
        (pl.col('mean_temperature').is_not_null())
    )
    .sort('mean_temperature', descending=True)
)
print(temperature)
# Out:
# shape: (3, 2)
# ┌──────────────┬──────────────────┐
# │ countryLabel ┆ mean_temperature │
# │ ---          ┆ ---              │
# │ str          ┆ f64              │
# ╞══════════════╪══════════════════╡
# │ França       ┆ 13.0             │
# │ Bulgária     ┆ 10.427273        │
# │ Alemanha     ┆ 3.0              │
# └──────────────┴──────────────────┘

# %%
length = (
    df.filter(
        (pl.col('length').is_not_null())
    )
)
print(length.head(5))
# Out:
# shape: (5, 8)
# ┌─────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────┐
# │     ┆ itemLabel  ┆ coordinate_l ┆ countryLabe ┆ temperature ┆ vertical_de ┆ elevation_a ┆ length │
# │ --- ┆ ---        ┆ ocation      ┆ l           ┆ ---         ┆ pth         ┆ bove_sea_le ┆ ---    │
# │ i64 ┆ str        ┆ ---          ┆ ---         ┆ f64         ┆ ---         ┆ vel         ┆ f64    │
# │     ┆            ┆ str          ┆ str         ┆             ┆ f64         ┆ ---         ┆        │
# │     ┆            ┆              ┆             ┆             ┆             ┆ f64         ┆        │
# ╞═════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════╡
# │ 3   ┆ Q101579973 ┆ Point(2.6650 ┆ França      ┆ null        ┆ null        ┆ 115.0       ┆ 31.0   │
# │     ┆            ┆ 1 48.40216)  ┆             ┆             ┆             ┆             ┆        │
# │ 10  ┆ Q105054041 ┆ Point(35.328 ┆ Israel      ┆ null        ┆ null        ┆ null        ┆ 168.0  │
# │     ┆            ┆ 7 31.99322)  ┆             ┆             ┆             ┆             ┆        │
# │ 28  ┆ Q106223935 ┆ Point(56.1   ┆ Rússia      ┆ null        ┆ null        ┆ null        ┆ 11.0   │
# │     ┆            ┆ 53.966666666 ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ )            ┆             ┆             ┆             ┆             ┆        │
# │ 29  ┆ Q106223935 ┆ Point(56.1   ┆ Rússia      ┆ null        ┆ null        ┆ null        ┆ 10.0   │
# │     ┆            ┆ 53.966666666 ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ )            ┆             ┆             ┆             ┆             ┆        │
# │ 50  ┆ Q107723805 ┆ Point(19.329 ┆ Polónia     ┆ null        ┆ null        ┆ null        ┆ 25.0   │
# │     ┆            ┆ 444444 50.67 ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 7777777)     ┆             ┆             ┆             ┆             ┆        │
# └─────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────┘

# %%
max_length = (
    length.group_by(pl.col(
        'countryLabel',
        'itemLabel',
        'coordinate_location',
        'vertical_depth'
        ))
    .agg(
        (pl.col('length').max())
    )
    .sort('length', descending=True)
).head(10)
print(max_length)
# Out:
# shape: (10, 5)
# ┌──────────────┬───────────────────────────┬───────────────────────────┬────────────────┬──────────┐
# │ countryLabel ┆ itemLabel                 ┆ coordinate_location       ┆ vertical_depth ┆ length   │
# │ ---          ┆ ---                       ┆ ---                       ┆ ---            ┆ ---      │
# │ str          ┆ str                       ┆ str                       ┆ f64            ┆ f64      │
# ╞══════════════╪═══════════════════════════╪═══════════════════════════╪════════════════╪══════════╡
# │ Ucrânia      ┆ Optymistychna Cave        ┆ Point(25.9737 48.7349)    ┆ 20.0           ┆ 264576.0 │
# │ Eslováquia   ┆ Baradla cave              ┆ Point(20.5 48.4667)       ┆ null           ┆ 25500.0  │
# │ Hungria      ┆ Baradla cave              ┆ Point(20.5 48.4667)       ┆ null           ┆ 25500.0  │
# │ Polónia      ┆ Jaskinia Wielka Śnieżna   ┆ Point(19.923055555 49.24) ┆ null           ┆ 23753.0  │
# │ Alemanha     ┆ Riesending-Schachthöhle   ┆ Point(12.9831 47.6994)    ┆ null           ┆ 19500.0  │
# │ Eslováquia   ┆ Jaskyna mrtvych           ┆ Point(19.638888888        ┆ null           ┆ 19260.0  │
# │              ┆ netopierov                ┆ 48.925)                   ┆                ┆          │
# │ Bulgária     ┆ Duhlata                   ┆ Point(23.195833333        ┆ 53.0           ┆ 18200.0  │
# │              ┆                           ┆ 42.495833333)             ┆                ┆          │
# │ Sérvia       ┆ Lazar's Cave              ┆ Point(21.9627 44.0293)    ┆ null           ┆ 16041.0  │
# │ Grécia       ┆ Diros cave                ┆ Point(22.380029           ┆ null           ┆ 15400.0  │
# │              ┆                           ┆ 36.638011)                ┆                ┆          │
# │ Bulgária     ┆ Orlova Chuka              ┆ Point(25.9603 43.5899)    ┆ null           ┆ 13437.0  │
# └──────────────┴───────────────────────────┴───────────────────────────┴────────────────┴──────────┘

# %%
vertical_depth = (
    df.filter(
        (pl.col('vertical_depth').is_not_null())
    )
)
print(vertical_depth.head(2))
# Out:
# shape: (2, 8)
# ┌─────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────┐
# │     ┆ itemLabel  ┆ coordinate_l ┆ countryLabe ┆ temperature ┆ vertical_de ┆ elevation_a ┆ length │
# │ --- ┆ ---        ┆ ocation      ┆ l           ┆ ---         ┆ pth         ┆ bove_sea_le ┆ ---    │
# │ i64 ┆ str        ┆ ---          ┆ ---         ┆ f64         ┆ ---         ┆ vel         ┆ f64    │
# │     ┆            ┆ str          ┆ str         ┆             ┆ f64         ┆ ---         ┆        │
# │     ┆            ┆              ┆             ┆             ┆             ┆ f64         ┆        │
# ╞═════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════╡
# │ 60  ┆ Q108795471 ┆ Point(20.280 ┆ Eslováquia  ┆ null        ┆ 18.0        ┆ null        ┆ 50.0   │
# │     ┆            ┆ 333          ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 49.237167)   ┆             ┆             ┆             ┆             ┆        │
# │ 62  ┆ Q108872201 ┆ Point(23.937 ┆ Bulgária    ┆ null        ┆ 8.0         ┆ 675.0       ┆ 102.0  │
# │     ┆            ┆ 5 42.2833333 ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 33)          ┆             ┆             ┆             ┆             ┆        │
# └─────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────┘

# %%
max_vertical_depth = (
    vertical_depth.group_by(
        pl.col([
            'countryLabel',
            'itemLabel',
            'coordinate_location',
            'length'
        ])
    )
    .agg(
        (pl.col('vertical_depth').max())
    )
    .sort('vertical_depth', descending=True)
).head(10)
print(max_vertical_depth)
# Out:
# shape: (10, 5)
# ┌──────────────┬───────────────────┬──────────────────────────────────┬────────┬────────────────┐
# │ countryLabel ┆ itemLabel         ┆ coordinate_location              ┆ length ┆ vertical_depth │
# │ ---          ┆ ---               ┆ ---                              ┆ ---    ┆ ---            │
# │ str          ┆ str               ┆ str                              ┆ f64    ┆ f64            │
# ╞══════════════╪═══════════════════╪══════════════════════════════════╪════════╪════════════════╡
# │ Geórgia      ┆ Veryovkina Cave   ┆ Point(40.35972 43.39753)         ┆ null   ┆ 2212.0         │
# │ Abecásia     ┆ Caverna Voronya   ┆ Point(40.362222222 43.409722222) ┆ null   ┆ 2199.0         │
# │ Geórgia      ┆ Caverna Voronya   ┆ Point(40.362222222 43.409722222) ┆ null   ┆ 2199.0         │
# │ Eslovénia    ┆ Skalarjevo brezno ┆ Point(13.4663 46.3567)           ┆ 8524.0 ┆ 1209.0         │
# │ Itália       ┆ Q3603719          ┆ Point(11.064416666 46.129694444) ┆ null   ┆ 387.0          │
# │ Bulgária     ┆ Raychova dupka    ┆ Point(24.6826 42.76848)          ┆ 1500.0 ┆ 377.0          │
# │ Bulgária     ┆ Barki 14          ┆ Point(23.458258333 43.220847222) ┆ 2600.0 ┆ 356.0          │
# │ Espanha      ┆ Lezetxiki         ┆ Point(-2.53333333 43.07472222)   ┆ null   ┆ 345.0          │
# │ Bulgária     ┆ Golyamata yama 3  ┆ Point(26.290805555 42.893027777) ┆ 740.0  ┆ 344.0          │
# │ Bulgária     ┆ Tizoin            ┆ Point(23.074738888 43.088919444) ┆ 3599.0 ┆ 320.0          │
# └──────────────┴───────────────────┴──────────────────────────────────┴────────┴────────────────┘

# %%
elevation_above_sea_level = (
    df.filter(
        (pl.col('elevation_above_sea_level').is_not_null())
    )
)
print(elevation_above_sea_level.head())
# Out:
# shape: (5, 8)
# ┌─────┬────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────┐
# │     ┆ itemLabel  ┆ coordinate_l ┆ countryLabe ┆ temperature ┆ vertical_de ┆ elevation_a ┆ length │
# │ --- ┆ ---        ┆ ocation      ┆ l           ┆ ---         ┆ pth         ┆ bove_sea_le ┆ ---    │
# │ i64 ┆ str        ┆ ---          ┆ ---         ┆ f64         ┆ ---         ┆ vel         ┆ f64    │
# │     ┆            ┆ str          ┆ str         ┆             ┆ f64         ┆ ---         ┆        │
# │     ┆            ┆              ┆             ┆             ┆             ┆ f64         ┆        │
# ╞═════╪════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════╡
# │ 3   ┆ Q101579973 ┆ Point(2.6650 ┆ França      ┆ null        ┆ null        ┆ 115.0       ┆ 31.0   │
# │     ┆            ┆ 1 48.40216)  ┆             ┆             ┆             ┆             ┆        │
# │ 53  ┆ Q108046952 ┆ Point(5.4023 ┆ França      ┆ null        ┆ null        ┆ 430.0       ┆ 50.0   │
# │     ┆            ┆ 06           ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 43.833956)   ┆             ┆             ┆             ┆             ┆        │
# │ 62  ┆ Q108872201 ┆ Point(23.937 ┆ Bulgária    ┆ null        ┆ 8.0         ┆ 675.0       ┆ 102.0  │
# │     ┆            ┆ 5 42.2833333 ┆             ┆             ┆             ┆             ┆        │
# │     ┆            ┆ 33)          ┆             ┆             ┆             ┆             ┆        │
# │ 85  ┆ Q111043273 ┆ Point(19.765 ┆ Polónia     ┆ null        ┆ null        ┆ 375.0       ┆ 4.0    │
# │     ┆            ┆ 50.165556)   ┆             ┆             ┆             ┆             ┆        │
# │ 197 ┆ Q11721274  ┆ Point(19.902 ┆ Polónia     ┆ null        ┆ 12.7        ┆ 215.0       ┆ 500.0  │
# │     ┆            ┆ 43 50.03894) ┆             ┆             ┆             ┆             ┆        │
# └─────┴────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────┘

# %%
max_elevation_above_sea_level = (
    elevation_above_sea_level.group_by(
        (pl.col([
            'countryLabel',
            'itemLabel',
            'coordinate_location',
            'vertical_depth',
            'length'
            
        ]))
    )
    .agg(
        (pl.col('elevation_above_sea_level').max().alias('max_elevation_above_sea_level'))
    )
    .sort('max_elevation_above_sea_level', descending=True)
)
print(max_elevation_above_sea_level.head())
# Out:
# shape: (5, 6)
# ┌──────────────┬───────────────────┬──────────────────┬────────────────┬────────┬──────────────────┐
# │ countryLabel ┆ itemLabel         ┆ coordinate_locat ┆ vertical_depth ┆ length ┆ max_elevation_ab │
# │ ---          ┆ ---               ┆ ion              ┆ ---            ┆ ---    ┆ ove_sea_level    │
# │ str          ┆ str               ┆ ---              ┆ f64            ┆ f64    ┆ ---              │
# │              ┆                   ┆ str              ┆                ┆        ┆ f64              │
# ╞══════════════╪═══════════════════╪══════════════════╪════════════════╪════════╪══════════════════╡
# │ Nepal        ┆ Milarepa Cave,    ┆ Point(84.0394    ┆ null           ┆ null   ┆ 13450.0          │
# │              ┆ Gandaki           ┆ 28.6369)         ┆                ┆        ┆                  │
# │ Chile        ┆ Cueva Granda      ┆ Point(-68.183333 ┆ null           ┆ null   ┆ 4662.0           │
# │              ┆                   ┆ 333              ┆                ┆        ┆                  │
# │              ┆                   ┆ -21.93333333…    ┆                ┆        ┆                  │
# │ Peru         ┆ Sima Pumacocha    ┆ Point(-75.7      ┆ null           ┆ null   ┆ 4375.0           │
# │              ┆                   ┆ -12.391388888)   ┆                ┆        ┆                  │
# │ Chile        ┆ Cueva Chica       ┆ Point(-68.183333 ┆ null           ┆ null   ┆ 4071.0           │
# │              ┆                   ┆ 333 -21.95)      ┆                ┆        ┆                  │
# │ Peru         ┆ Mollepunco        ┆ Point(-71.415302 ┆ null           ┆ null   ┆ 3996.0           │
# │              ┆                   ┆ 777              ┆                ┆        ┆                  │
# │              ┆                   ┆ -15.54463055…    ┆                ┆        ┆                  │
# └──────────────┴───────────────────┴──────────────────┴────────────────┴────────┴──────────────────┘

# %%
def map_generator(dataframe, initial_coord):
    map = folium.Map(location=initial_coord, zoom_start=5)
    df = dataframe
    for coord, name, country, length, vertical_depth in zip(df['coordinate_location'], df['itemLabel'], df['countryLabel'], df['length'], df['vertical_depth']):
        html = f"""
        <h4>Name: {name}</h4>
        <h5>Country: {country}</h5>
        <h5>Length: {length}</h5>
        <h5>Vertical Depth: {vertical_depth}</h5>
        <h6>
        Coordinates:
        <code>
            {coord}
        </code>
        </h6>
        """
        popup_text = html
        lon, lat = wkt.loads(coord).xy
        folium.Marker(location=[lat[0], lon[0]], popup=popup_text).add_to(map)

    return map

# %% [markdown]
# ## Cavernas no Brasil

# %%
map = map_generator(df_brasil, [-14.235004, -51.92528])
map.save('cave_brasil.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5958578b7e59d98ebb5d2681f285cb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5958578b7e59d98ebb5d2681f285cb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5958578b7e59d98ebb5d2681f285cb7 = L.map(
#                 &quot;map_e5958578b7e59d98ebb5d2681f285cb7&quot;,
#                 {
#                     center: [-14.235004, -51.92528],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afa34a45d561bc5a9ef1247f1a4129cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_afa34a45d561bc5a9ef1247f1a4129cd.addTo(map_e5958578b7e59d98ebb5d2681f285cb7);
#
#
#             var marker_377f6d5b1b188560c0d9642161a83bbb = L.marker(
#                 [-20.180847, -40.570406],
#                 {}
#             ).addTo(map_e5958578b7e59d98ebb5d2681f285cb7);
#
#
#         var popup_29bd270ce6eb824260d64ff8905d7482 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5b192ef3c624d7a2e9ba2058892550e = $(`&lt;div id=&quot;html_c5b192ef3c624d7a2e9ba2058892550e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Q114347515&lt;/h4&gt;         &lt;h5&gt;Country: Brasil&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(-40.570406 -20.180847)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_29bd270ce6eb824260d64ff8905d7482.setContent(html_c5b192ef3c624d7a2e9ba2058892550e);
#
#
#
#         marker_377f6d5b1b188560c0d9642161a83bbb.bindPopup(popup_29bd270ce6eb824260d64ff8905d7482)
#         ;
#
#
#
#
#             var marker_bf0090f9124e523ece8ce87ac89ceaa1 = L.marker(
#                 [-24.5446, -48.6795],
#                 {}
#             ).addTo(map_e5958578b7e59d98ebb5d2681f285cb7);
#
#
#         var popup_2f7d619f3382d10c6d587bf842e54764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b4fb4c198f0c161c5edd7daf0d5b3ca = $(`&lt;div id=&quot;html_5b4fb4c198f0c161c5edd7daf0d5b3ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Abismo Ouro Grosso&lt;/h4&gt;         &lt;h5&gt;Country: Brasil&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(-48.6795 -24.5446)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_2f7d619f3382d10c6d587bf842e54764.setContent(html_5b4fb4c198f0c161c5edd7daf0d5b3ca);
#
#
#
#         marker_bf0090f9124e523ece8ce87ac89ceaa1.bindPopup(popup_2f7d619f3382d10c6d587bf842e54764)
#         ;
#
#
#
#
#             var marker_7d5f80f335831f5504217375790f0888 = L.marker(
#                 [-13.6685, -46.3671],
#                 {}
#             ).addTo(map_e5958578b7e59d98ebb5d2681f285cb7);
#
#
#         var popup_d1f83faee3ed330fc9d3d6e6938c8ded = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2780d1ff779cc12e3e38e9c8aaaf5367 = $(`&lt;div id=&quot;html_2780d1ff779cc12e3e38e9c8aaaf5367&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Areado Grande&lt;/h4&gt;         &lt;h5&gt;Country: Brasil&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(-46.3671 -13.6685)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_d1f83faee3ed330fc9d3d6e6938c8ded.setContent(html_2780d1ff779cc12e3e38e9c8aaaf5367);
#
#
#
#         marker_7d5f80f335831f5504217375790f0888.bindPopup(popup_d1f83faee3ed330fc9d3d6e6938c8ded)
#         ;
#
#
#
#
#             var marker_e041d72adc2475e6fe57de31d15e0d78 = L.marker(
#                 [-15.8688, -55.38311],
#                 {}
#             ).addTo(map_e5958578b7e59d98ebb5d2681f285cb7);
#
#
#         var popup_829cd5ba62dd5594ebbc7bfe249f1711 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cddf017170d6491141e10c1b49ca1faa = $(`&lt;div id=&quot;html_cddf017170d6491141e10c1b49ca1faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Cave of Saint Vincent&lt;/h4&gt;         &lt;h5&gt;Country: Brasil&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(-55.38311 -15.8688)         &l

# %% [markdown]
# ## Maiores Cavernas

# %%
map = map_generator(max_length, [51.359441, 23.660791])
map.save('max_length.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9364a894f2195f787c563194139901aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9364a894f2195f787c563194139901aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9364a894f2195f787c563194139901aa = L.map(
#                 &quot;map_9364a894f2195f787c563194139901aa&quot;,
#                 {
#                     center: [51.359441, 23.660791],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a7e7d51d81bff25d27a661547944a39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a7e7d51d81bff25d27a661547944a39.addTo(map_9364a894f2195f787c563194139901aa);
#
#
#             var marker_7ddd4280627d6610454073e999785ff5 = L.marker(
#                 [48.7349, 25.9737],
#                 {}
#             ).addTo(map_9364a894f2195f787c563194139901aa);
#
#
#         var popup_e0cf0222a561a251c1e45ac397200189 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_916ccef459d724a0f71772b5e983fc97 = $(`&lt;div id=&quot;html_916ccef459d724a0f71772b5e983fc97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Optymistychna Cave&lt;/h4&gt;         &lt;h5&gt;Country: Ucrânia&lt;/h5&gt;         &lt;h5&gt;Length: 264576.0&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: 20.0&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(25.9737 48.7349)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_e0cf0222a561a251c1e45ac397200189.setContent(html_916ccef459d724a0f71772b5e983fc97);
#
#
#
#         marker_7ddd4280627d6610454073e999785ff5.bindPopup(popup_e0cf0222a561a251c1e45ac397200189)
#         ;
#
#
#
#
#             var marker_3f4a7417c1b35cb0ab8429637c39a044 = L.marker(
#                 [48.4667, 20.5],
#                 {}
#             ).addTo(map_9364a894f2195f787c563194139901aa);
#
#
#         var popup_8eb08ba771229ede1adb8b704ea65289 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_906e5570699597de1910aa425ebe6587 = $(`&lt;div id=&quot;html_906e5570699597de1910aa425ebe6587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Baradla cave&lt;/h4&gt;         &lt;h5&gt;Country: Eslováquia&lt;/h5&gt;         &lt;h5&gt;Length: 25500.0&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(20.5 48.4667)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_8eb08ba771229ede1adb8b704ea65289.setContent(html_906e5570699597de1910aa425ebe6587);
#
#
#
#         marker_3f4a7417c1b35cb0ab8429637c39a044.bindPopup(popup_8eb08ba771229ede1adb8b704ea65289)
#         ;
#
#
#
#
#             var marker_56f6bf45243b7b3ab5e65c69bc8e37bf = L.marker(
#                 [48.4667, 20.5],
#                 {}
#             ).addTo(map_9364a894f2195f787c563194139901aa);
#
#
#         var popup_e00960b7aefaf626682946f72629301e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9e2054ba7a3627ca808f74a085363e1 = $(`&lt;div id=&quot;html_b9e2054ba7a3627ca808f74a085363e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Baradla cave&lt;/h4&gt;         &lt;h5&gt;Country: Hungria&lt;/h5&gt;         &lt;h5&gt;Length: 25500.0&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(20.5 48.4667)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_e00960b7aefaf626682946f72629301e.setContent(html_b9e2054ba7a3627ca808f74a085363e1);
#
#
#
#         marker_56f6bf45243b7b3ab5e65c69bc8e37bf.bindPopup(popup_e00960b7aefaf626682946f72629301e)
#         ;
#
#
#
#
#             var marker_6c2169e7d3da57a92fff49cfcbd13c7b = L.marker(
#                 [49.24, 19.923055555],
#                 {}
#             ).addTo(map_9364a894f2195f787c563194139901aa);
#
#
#         var popup_6c836b0f04794a0d8b64199352783afb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_483d2f7c230bed5f5d99f90451c2ade8 = $(`&lt;div id=&quot;html_483d2f7c230bed5f5d99f90451c2ade8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Jaskinia Wielka Śnieżna&lt;/h4&gt;         &lt;h5&gt;Country: Polónia&lt;/h5&gt;         &lt;h5&gt;Length: 23753.0&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: None&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(19.923055555 49.24)         &lt;/code&gt

# %% [markdown]
# ## Cavernas Mais Profundas

# %%
map = map_generator(max_vertical_depth, [51.359441, 23.660791])
map.save('max_vertical_depth.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1cd16079f018230c4b92760bb16badf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1cd16079f018230c4b92760bb16badf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1cd16079f018230c4b92760bb16badf = L.map(
#                 &quot;map_d1cd16079f018230c4b92760bb16badf&quot;,
#                 {
#                     center: [51.359441, 23.660791],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_605281f98dd4169d6b76cfd83805e8a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_605281f98dd4169d6b76cfd83805e8a7.addTo(map_d1cd16079f018230c4b92760bb16badf);
#
#
#             var marker_57370efef00891c758a021c232071e7f = L.marker(
#                 [43.39753, 40.35972],
#                 {}
#             ).addTo(map_d1cd16079f018230c4b92760bb16badf);
#
#
#         var popup_07804494c58a7b5f74545fc772085630 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab47fe043965b82f76c47e127bfd9ea2 = $(`&lt;div id=&quot;html_ab47fe043965b82f76c47e127bfd9ea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Veryovkina Cave&lt;/h4&gt;         &lt;h5&gt;Country: Geórgia&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: 2212.0&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(40.35972 43.39753)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_07804494c58a7b5f74545fc772085630.setContent(html_ab47fe043965b82f76c47e127bfd9ea2);
#
#
#
#         marker_57370efef00891c758a021c232071e7f.bindPopup(popup_07804494c58a7b5f74545fc772085630)
#         ;
#
#
#
#
#             var marker_bfab3ef6cd782902e3002c95b52e4214 = L.marker(
#                 [43.409722222, 40.362222222],
#                 {}
#             ).addTo(map_d1cd16079f018230c4b92760bb16badf);
#
#
#         var popup_d18f5c947abbed1978865c659b119fd5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f38a49402fefa23183483557f7c6f5c5 = $(`&lt;div id=&quot;html_f38a49402fefa23183483557f7c6f5c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Caverna Voronya&lt;/h4&gt;         &lt;h5&gt;Country: Abecásia&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: 2199.0&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(40.362222222 43.409722222)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_d18f5c947abbed1978865c659b119fd5.setContent(html_f38a49402fefa23183483557f7c6f5c5);
#
#
#
#         marker_bfab3ef6cd782902e3002c95b52e4214.bindPopup(popup_d18f5c947abbed1978865c659b119fd5)
#         ;
#
#
#
#
#             var marker_bc3a5889c74589d9fbab0fb8e9ce2d2f = L.marker(
#                 [43.409722222, 40.362222222],
#                 {}
#             ).addTo(map_d1cd16079f018230c4b92760bb16badf);
#
#
#         var popup_72006e4aa1f92c3a4e0e603cc36ae22e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f575d9f54f5d85b6382307acf8c2c9cd = $(`&lt;div id=&quot;html_f575d9f54f5d85b6382307acf8c2c9cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Caverna Voronya&lt;/h4&gt;         &lt;h5&gt;Country: Geórgia&lt;/h5&gt;         &lt;h5&gt;Length: None&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: 2199.0&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;             Point(40.362222222 43.409722222)         &lt;/code&gt;         &lt;/h6&gt;         &lt;/div&gt;`)[0];
#                 popup_72006e4aa1f92c3a4e0e603cc36ae22e.setContent(html_f575d9f54f5d85b6382307acf8c2c9cd);
#
#
#
#         marker_bc3a5889c74589d9fbab0fb8e9ce2d2f.bindPopup(popup_72006e4aa1f92c3a4e0e603cc36ae22e)
#         ;
#
#
#
#
#             var marker_e7a9f5ade7afa04ca8ca3eb2c6b3181f = L.marker(
#                 [46.3567, 13.4663],
#                 {}
#             ).addTo(map_d1cd16079f018230c4b92760bb16badf);
#
#
#         var popup_79fb7a0e7240983c672f0270d07e5b9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_636b57b0d213e252dec1119268052f15 = $(`&lt;div id=&quot;html_636b57b0d213e252dec1119268052f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Name: Skalarjevo brezno&lt;/h4&gt;         &lt;h5&gt;Country: Eslovénia&lt;/h5&gt;         &lt;h5&gt;Length: 8524.0&lt;/h5&gt;         &lt;h5&gt;Vertical Depth: 1209.0&lt;/h5&gt;         &lt;h6&gt;         Coordinates:         &lt;code&gt;
